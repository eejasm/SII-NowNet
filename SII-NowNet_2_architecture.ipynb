# %%
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import backend as K

# %%
# Building the convolutional block
def ConvBlock(inputs, filters):
    # Taking first input and implementing the first conv block
    conv1 = layers.Conv2D(filters, kernel_size = (3,3), padding = "same")(inputs)
    batch_norm1 = layers.BatchNormalization()(conv1)
    act1 = layers.ReLU()(batch_norm1)
    
    # Taking first input and implementing the second conv block
    conv2 = layers.Conv2D(filters, kernel_size = (3,3), padding = "same")(act1)
    batch_norm2 = layers.BatchNormalization()(conv2)
    act2 = layers.ReLU()(batch_norm2)
    
    return act2

# Building the encoder
def encoder(inputs, filters=64):
    # Collect the start and end of each sub-block for normal pass and skip connections
    enc1 = ConvBlock(inputs, filters)
    MaxPool1 = layers.MaxPooling2D(strides = (2,2))(enc1)
    return enc1, MaxPool1

# Building the decoder
def decoder(inputs, skip, filters=64):
    # Upsampling and concatenating the essential features
    Upsample = layers.Conv2DTranspose(filters, (2, 2), strides=2, padding="same")(inputs)
    Connect_Skip = layers.Concatenate()([Upsample, skip])
    out = ConvBlock(Connect_Skip, filters)
    return out

# %%
inputs = layers.Input((416,416,2))
    
# Construct the encoder blocks and increasing the filters by a factor of 2
skip1, encoder_1 = encoder(inputs, 64)
skip2, encoder_2 = encoder(encoder_1, 64*2)
skip3, encoder_3 = encoder(encoder_2, 64*4)
skip4, encoder_4 = encoder(encoder_3, 64*8)

# Preparing the next block
conv_block = ConvBlock(encoder_4, 64*16)
# Out:
# 2025-09-22 16:56:29.199893: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-09-22 16:56:30.955438: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 30927 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB-LS, pci bus id: 0000:85:00.0, compute capability: 7.0
# 2025-09-22 16:56:30.959042: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 30927 MB memory:  -> device: 1, name: Tesla V100-SXM2-32GB-LS, pci bus id: 0000:86:00.0, compute capability: 7.0

# %%
# Construct the decoder blocks and decreasing the filters by a factor of 2
decoder_1 = decoder(conv_block, skip4, 64*8)
decoder_2 = decoder(decoder_1, skip3, 64*4)
decoder_3 = decoder(decoder_2, skip2, 64*2)
decoder_4 = decoder(decoder_3, skip1, 64)

outputs = layers.Conv2D(1, 1, padding="same", activation="sigmoid")(decoder_4)
outputs = layers.MaxPooling2D(strides = (16,16))(outputs)

model = models.Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 416, 416, 2  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 416, 416, 64  1216        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 416, 416, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  re_lu (ReLU)                   (None, 416, 416, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 416, 416, 64  36928       ['re_lu[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 416, 416, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  re_lu_1 (ReLU)                 (None, 416, 416, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 208, 208, 64  0           ['re_lu_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 208, 208, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 208, 208, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  re_lu_2 (ReLU)                 (None, 208, 208, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 208, 208, 12  147584      ['re_lu_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 208, 208, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  re_lu_3 (ReLU)                 (None, 208, 208, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 104, 104, 12  0          ['re_lu_3[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 104, 104, 25  295168      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 104, 104, 25  1024       ['conv2d_4[0][0]']
#  rmalization)                   6)
#
#  re_lu_4 (ReLU)                 (None, 104, 104, 25  0           ['batch_normalization_4[0][0]']
#                                 6)
#
#  conv2d_5 (Conv2D)              (None, 104, 104, 25  590080      ['re_lu_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 104, 104, 25  1024       ['conv2d_5[0][0]']
#  rmalization)                   6)
#
#  re_lu_5 (ReLU)                 (None, 104, 104, 25  0           ['batch_normalization_5[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 52, 52, 256)  0          ['re_lu_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 52, 52, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 52, 52, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  re_lu_6 (ReLU)                 (None, 52, 52, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 52, 52, 512)  2359808     ['re_lu_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 52, 52, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  re_lu_7 (ReLU)                 (None, 52, 52, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 26, 26, 512)  0          ['re_lu_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 26, 26, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 26, 26, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  re_lu_8 (ReLU)                 (None, 26, 26, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 26, 26, 1024  9438208     ['re_lu_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 26, 26, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  re_lu_9 (ReLU)                 (None, 26, 26, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 52, 52, 512)  2097664    ['re_lu_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 52, 52, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 're_lu_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 52, 52, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 52, 52, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  re_lu_10 (ReLU)                (None, 52, 52, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 52, 52, 512)  2359808     ['re_lu_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 52, 52, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  re_lu_11 (ReLU)                (None, 52, 52, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 104, 104, 25  524544     ['re_lu_11[0][0]']
#  spose)                         6)
#
#  concatenate_1 (Concatenate)    (None, 104, 104, 51  0           ['conv2d_transpose_1[0][0]',
#                                 2)                                're_lu_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 104, 104, 25  1179904     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_12 (BatchN  (None, 104, 104, 25  1024       ['conv2d_12[0][0]']
#  ormalization)                  6)
#
#  re_lu_12 (ReLU)                (None, 104, 104, 25  0           ['batch_normalization_12[0][0]']
#                                 6)
#
#  conv2d_13 (Conv2D)             (None, 104, 104, 25  590080      ['re_lu_12[0][0]']
#                                 6)
#
#  batch_normalization_13 (BatchN  (None, 104, 104, 25  1024       ['conv2d_13[0][0]']
#  ormalization)                  6)
#
#  re_lu_13 (ReLU)                (None, 104, 104, 25  0           ['batch_normalization_13[0][0]']
#                                 6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 208, 208, 12  131200     ['re_lu_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 208, 208, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                're_lu_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 208, 208, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 208, 208, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  re_lu_14 (ReLU)                (None, 208, 208, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 208, 208, 12  147584      ['re_lu_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 208, 208, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  re_lu_15 (ReLU)                (None, 208, 208, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 416, 416, 64  32832      ['re_lu_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 416, 416, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                're_lu_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 416, 416, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 416, 416, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  re_lu_16 (ReLU)                (None, 416, 416, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 416, 416, 64  36928       ['re_lu_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 416, 416, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  re_lu_17 (ReLU)                (None, 416, 416, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 416, 416, 1)  65          ['re_lu_17[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 26, 26, 1)   0           ['conv2d_18[0][0]']
#
# ==================================================================================================
# Total params: 31,054,721
# Trainable params: 31,042,945
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %%
# Learning_rate=0.001 can be tuned for better performance  
model.compile(optimizer=keras.optimizers.Adam(learning_rate = 0.001), loss=['binary_crossentropy'], metrics=keras.metrics.AUC())

early_stopping = EarlyStopping(
        monitor = 'val_loss',
        min_delta=0.000001, # minimium amount of change to count as an improvement
        patience=2, # how many epochs to wait before stopping
        restore_best_weights=True,
        mode='auto'
)

# %% [markdown]
# Run this line when you have the training/validation data prepared and you want to train the model

# %%
#history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs = 100, callbacks = [early_stopping], batch_size=4)
